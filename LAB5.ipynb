# %% [markdown]
# <a href="https://colab.research.google.com/github/denverkim/ALGORITHM/blob/main/LAB5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import the en.openfoodfacts.org.products.tsv dataset and assign it to a dataframe called food. 세계음식 팩트파일을 임포트해서 food 라는 데이터 프레임에 넣으시오.

import pandas as pd

food = pd.read_csv('/content/en.openfoodfacts.org.products.tsv', delimiter='\t', low_memory=False)

# %%
# Display the first 5 rows. 처음 5줄
print('상위 5개 데이터', food.head())

# What is the number of observations in the dataset? 관측치의 갯수
print('관측치 갯수: ', food.shape[0])

# What is the number of columns in the dataset? 컬럼의 수
print('컬럼의 갯수: ', food.shape[1])

# Print the name of all the columns. 모든 컬럼의 이름
list(food.columns)
# Out:
# 상위 5개 데이터             code                                                url  \
# 0  0000000003087  http://world-en.openfoodfacts.org/product/0000...
# 1  0000000004530  http://world-en.openfoodfacts.org/product/0000...
# 2  0000000004559  http://world-en.openfoodfacts.org/product/0000...
# 3  0000000016087  http://world-en.openfoodfacts.org/product/0000...
# 4  0000000016094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#    last_modified_t last_modified_datetime                    product_name  \
# 0       1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# ...

# %%
# What is the name of 105th column? 105번째 컬럼의 이름은?
food.columns[104]

# What is the data type of the observations of the 105th column? 105번째 컬럼의 데이터 타입
print(food.dtypes[104])

# How is the dataset indexed? 데이터셋은 어떻게 인덱스 되었나요?
print(food.index)

# What is the product name of the 19th observation? 19번째 관측치의 상품 이름은?
food.product_name[18]
# Out:
# float64
# RangeIndex(start=0, stop=142531, step=1)
# /tmp/ipykernel_6229/4141154872.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(food.dtypes[104])
# 'Lotus Organic Brown Jasmine Rice'

# %% [markdown]
# # CHIPOTLE 예제

# %%
# Import the chipo dataset and assign it to a variable called chipo.
# 데이터셋을 임포트해서 chipo라고 하시오.

chipo = pd.read_excel('/content/chipotle.xlsx')

# Display the first 10 rows. 처음 10줄
chipo.head(10)

# What is the number of observations in the dataset? 관측치의 갯수는?
chipo.shape[0]

# What is the number of columns in the dataset? 컬럼의 수는?
chipo.shape[1]

# Print the name of all the columns. 모든 컬럼의 이름을 출력
chipo.columns

# How is the dataset indexed? 데이터셋은 어떻게 인덱스 되었나요?
chipo.index

# How many items were ordered in total?
# 전체 주문 아이템수는? Quantity의 합
print(chipo.quantity.sum())

# How much was the revenue for the period in the dataset?
# 데이터셋 안에 있는 기간에 대한 수익은 얼마인가요?
print('전체 수익: ', (chipo.quantity * chipo.item_price).sum())

# Which was the most-ordered item? 가장 많이 주문된 아이템은? Item_name에 따라 groupby된 것중 가장 카운트가 많이 된 것을 찾음
print('가장 많이 주문된 아이템: ', chipo.groupby('item_name').count().order_id.sort_values(ascending=False).index[0])

# For the most-ordered item, how many items were ordered? 가장 많이 주문된 아이템은 몇개나 주문됐나요? Groupby된것의 카운트수
print('가장 많이 주문된 아이템의 갯수: ', chipo.groupby('item_name').count().order_id.sort_values(ascending=False)[0])

chipo.item_name.value_counts()[0]

# What was the most ordered item in the choice_description column? choice_description컬럼에서 가장 많이 주문된 아이템은? choice_description에 따라 groupby된 것중 가장 카운트가 많은 것

# How many different items are sold? 얼마나 많은 다른 종류의 아이템이 팔렸나요?
chipo.item_name.nunique()
# Out:
# 4972
# 전체 수익:  39237.02
# 가장 많이 주문된 아이템:  Chicken Bowl
# 가장 많이 주문된 아이템의 갯수:  726
# /tmp/ipykernel_6229/3575271636.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print('가장 많이 주문된 아이템의 갯수: ', chipo.groupby('item_name').count().order_id.sort_values(ascending=False)[0])
# /tmp/ipykernel_6229/3575271636.py:35: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chipo.item_name.value_counts()[0]
# 50

# %%
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...
